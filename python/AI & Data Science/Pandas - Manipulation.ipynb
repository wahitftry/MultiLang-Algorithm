# %%
import pandas as pd

# %%
df = pd.read_csv('./CSV_UMKM_Jabar.csv')

# %%
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 157  158             32    JAWA BARAT                 3275
# 158  159             32    JAWA BARAT                 3276
# 159  160             32    JAWA BARAT                 3277
# 160  161             32    JAWA BARAT                 3278
# 161  162             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_umkm satuan  tahun
# 0       KABUPATEN BOGOR       375048   UNIT   2016
# 1    KABUPATEN SUKABUMI       269002   UNIT   2016
# 2     KABUPATEN CIANJUR       250808   UNIT   2016
# ...

# %%
df.iloc[0:2, [0,1]]
# Out:
#    id  kode_provinsi
# 0   1             32
# 1   2             32

# %%
df.loc[0:2, ['nama_kabupaten_kota', 'jumlah_umkm']]
# Out:
#   nama_kabupaten_kota  jumlah_umkm
# 0     KABUPATEN BOGOR       375048
# 1  KABUPATEN SUKABUMI       269002
# 2   KABUPATEN CIANJUR       250808

# %%
df.loc[df['jumlah_umkm'] > 250000]
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# 8      9             32    JAWA BARAT                 3209
# 20    21             32    JAWA BARAT                 3273
# 27    28             32    JAWA BARAT                 3201
# 28    29             32    JAWA BARAT                 3202
# 29    30             32    JAWA BARAT                 3203
# 30    31             32    JAWA BARAT                 3204
# 31    32             32    JAWA BARAT                 3205
# 35    36             32    JAWA BARAT                 3209
# 47    48             32    JAWA BARAT                 3273
# 54    55             32    JAWA BARAT                 3201
# ...

# %%
df_filtered = df.loc[df['jumlah_umkm'] > 300000]

# %%
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_umkm satuan  tahun
# 0       375048   UNIT   2016
# 1       269002   UNIT   2016
# 2       250808   UNIT   2016
# 3       353277   UNIT   2016
# 4       259141   UNIT   2016

# %%
df_filtered
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 3      4             32    JAWA BARAT                 3204
# 20    21             32    JAWA BARAT                 3273
# 27    28             32    JAWA BARAT                 3201
# 30    31             32    JAWA BARAT                 3204
# 47    48             32    JAWA BARAT                 3273
# 54    55             32    JAWA BARAT                 3201
# 55    56             32    JAWA BARAT                 3202
# 57    58             32    JAWA BARAT                 3204
# 74    75             32    JAWA BARAT                 3273
# 81    82             32    JAWA BARAT                 3201
# 82    83             32    JAWA BARAT                 3202
# 83    84             32    JAWA BARAT                 3203
# 84    85             32    JAWA BARAT                 3204
# 85    86             32    JAWA BARAT                 3205
# ...

# %%
df.loc[df['jumlah_umkm'] > 300000, ['nama_kabupaten_kota']]
# Out:
#     nama_kabupaten_kota
# 0       KABUPATEN BOGOR
# 3     KABUPATEN BANDUNG
# 20         KOTA BANDUNG
# 27      KABUPATEN BOGOR
# 30    KABUPATEN BANDUNG
# 47         KOTA BANDUNG
# 54      KABUPATEN BOGOR
# 55   KABUPATEN SUKABUMI
# 57    KABUPATEN BANDUNG
# 74         KOTA BANDUNG
# 81      KABUPATEN BOGOR
# 82   KABUPATEN SUKABUMI
# 83    KABUPATEN CIANJUR
# 84    KABUPATEN BANDUNG
# 85      KABUPATEN GARUT
# 89    KABUPATEN CIREBON
# 101        KOTA BANDUNG
# 108     KABUPATEN BOGOR
# 109  KABUPATEN SUKABUMI
# 110   KABUPATEN CIANJUR
# 111   KABUPATEN BANDUNG
# 112     KABUPATEN GARUT
# 116   KABUPATEN CIREBON
# 128        KOTA BANDUNG
# 135     KABUPATEN BOGOR
# 136  KABUPATEN SUKABUMI
# 137   KABUPATEN CIANJUR
# 138   KABUPATEN BANDUNG
# 139     KABUPATEN GARUT
# 143   KABUPATEN CIREBON
# 149  KABUPATEN KARAWANG
# 150    KABUPATEN BEKASI
# 155        KOTA BANDUNG

# %%
df[df['jumlah_umkm'].isin([506347, 464346])]
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 135  136             32    JAWA BARAT                 3201
# 155  156             32    JAWA BARAT                 3273
#
#     nama_kabupaten_kota  jumlah_umkm satuan  tahun
# 135     KABUPATEN BOGOR       506347   UNIT   2021
# 155        KOTA BANDUNG       464346   UNIT   2021

# %%
df_506347_464346 = df[df['jumlah_umkm'].isin([506347, 464346])]

# %%
df_506347_464346
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 135  136             32    JAWA BARAT                 3201
# 155  156             32    JAWA BARAT                 3273
#
#     nama_kabupaten_kota  jumlah_umkm satuan  tahun
# 135     KABUPATEN BOGOR       506347   UNIT   2021
# 155        KOTA BANDUNG       464346   UNIT   2021

# %%
import numpy as np

condition1 = (df['jumlah_umkm'] >= 250000)
condition2 = (df['tahun'] >= 2020)

# %%
df.loc[np.where(condition1 & condition2)]
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 108  109             32    JAWA BARAT                 3201
# 109  110             32    JAWA BARAT                 3202
# 110  111             32    JAWA BARAT                 3203
# 111  112             32    JAWA BARAT                 3204
# 112  113             32    JAWA BARAT                 3205
# 116  117             32    JAWA BARAT                 3209
# 122  123             32    JAWA BARAT                 3215
# 123  124             32    JAWA BARAT                 3216
# 128  129             32    JAWA BARAT                 3273
# 130  131             32    JAWA BARAT                 3275
# 135  136             32    JAWA BARAT                 3201
# 136  137             32    JAWA BARAT                 3202
# 137  138             32    JAWA BARAT                 3203
# 138  139             32    JAWA BARAT                 3204
# 139  140             32    JAWA BARAT                 3205
# ...

# %%
df.sort_values(by=['jumlah_umkm'], ascending=False)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 135  136             32    JAWA BARAT                 3201
# 138  139             32    JAWA BARAT                 3204
# 108  109             32    JAWA BARAT                 3201
# 155  156             32    JAWA BARAT                 3273
# 111  112             32    JAWA BARAT                 3204
# ..   ...            ...           ...                  ...
# 134  135             32    JAWA BARAT                 3279
# 107  108             32    JAWA BARAT                 3279
# 80    81             32    JAWA BARAT                 3279
# 53    54             32    JAWA BARAT                 3279
# 26    27             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_umkm satuan  tahun
# 135     KABUPATEN BOGOR       506347   UNIT   2021
# 138   KABUPATEN BANDUNG       476954   UNIT   2021
# 108     KABUPATEN BOGOR       476844   UNIT   2020
# ...

# %%
df_sort = df.sort_values(by=['jumlah_umkm'], ascending=False)

# %%
df_sort
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 135  136             32    JAWA BARAT                 3201
# 138  139             32    JAWA BARAT                 3204
# 108  109             32    JAWA BARAT                 3201
# 155  156             32    JAWA BARAT                 3273
# 111  112             32    JAWA BARAT                 3204
# ..   ...            ...           ...                  ...
# 134  135             32    JAWA BARAT                 3279
# 107  108             32    JAWA BARAT                 3279
# 80    81             32    JAWA BARAT                 3279
# 53    54             32    JAWA BARAT                 3279
# 26    27             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_umkm satuan  tahun
# 135     KABUPATEN BOGOR       506347   UNIT   2021
# 138   KABUPATEN BANDUNG       476954   UNIT   2021
# 108     KABUPATEN BOGOR       476844   UNIT   2020
# ...

# %%
df['level'] = np.where(df['jumlah_umkm'] > 250000, 'High' , 'low')

# %%
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_umkm satuan  tahun level
# 0       375048   UNIT   2016  High
# 1       269002   UNIT   2016  High
# 2       250808   UNIT   2016  High
# 3       353277   UNIT   2016  High
# 4       259141   UNIT   2016  High

# %%
df.groupby('level')['jumlah_umkm'].agg(['mean', 'sum'])
# Out:
#                 mean       sum
# level
# High   334938.092593  18086657
# low    133290.879630  14395415

# %%
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_umkm satuan  tahun level
# 0       375048   UNIT   2016  High
# 1       269002   UNIT   2016  High
# 2       250808   UNIT   2016  High
# 3       353277   UNIT   2016  High
# 4       259141   UNIT   2016  High

# %%
add_df = pd.DataFrame({'kode_provinsi' : [32, 32],
                       'nama_provinsi' : ['Jawa Barat', 'Jawa Barat'],
                       'kode_kabupaten_kota': [3241, 3279],
                       'nama_kabupaten_kota': ['Kota Bogor', 'Kota Depok'],
                       'jumlah_umkm': [230000, 300000],
                       'tahun' : [2020, 2021],
                       'level' : ['low', 'high']})

more_df = pd.DataFrame({'id': [11,12,13],
                        'nama_kabupaten_kota': ['kabupaten pengalengan', 'kabupaten garut', 'kabupaten tasikmalaya'],
                        'tahun': [2021,2021,2021]})

# %%
add_df
# Out:
#    kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0             32    Jawa Barat                 3241          Kota Bogor
# 1             32    Jawa Barat                 3279          Kota Depok
#
#    jumlah_umkm  tahun level
# 0       230000   2020   low
# 1       300000   2021  high

# %%
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_umkm satuan  tahun level
# 0       375048   UNIT   2016  High
# 1       269002   UNIT   2016  High
# 2       250808   UNIT   2016  High
# 3       353277   UNIT   2016  High
# 4       259141   UNIT   2016  High

# %%
frames = [df, add_df]

new_df = pd.concat(frames, axis=0)

# %%
new_df.tail()
# Out:
#         id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 159  160.0             32    JAWA BARAT                 3277
# 160  161.0             32    JAWA BARAT                 3278
# 161  162.0             32    JAWA BARAT                 3279
# 0      NaN             32    Jawa Barat                 3241
# 1      NaN             32    Jawa Barat                 3279
#
#     nama_kabupaten_kota  jumlah_umkm satuan  tahun level
# 159         KOTA CIMAHI        76833   UNIT   2021   low
# 160    KOTA TASIKMALAYA       123010   UNIT   2021   low
# 161         KOTA BANJAR        34962   UNIT   2021   low
# 0            Kota Bogor       230000    NaN   2020   low
# 1            Kota Depok       300000    NaN   2021  high

# %%
more_df
# Out:
#    id    nama_kabupaten_kota  tahun
# 0  11  kabupaten pengalengan   2021
# 1  12        kabupaten garut   2021
# 2  13  kabupaten tasikmalaya   2021

# %%
pd.options.display.max_rows = 9999

# %%
df = pd.read_csv('./CSV_UMKM_Jabar.csv')

# %%
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# 5      6             32    JAWA BARAT                 3206
# 6      7             32    JAWA BARAT                 3207
# 7      8             32    JAWA BARAT                 3208
# 8      9             32    JAWA BARAT                 3209
# 9     10             32    JAWA BARAT                 3210
# 10    11             32    JAWA BARAT                 3211
# 11    12             32    JAWA BARAT                 3212
# 12    13             32    JAWA BARAT                 3213
# 13    14             32    JAWA BARAT                 3214
# 14    15             32    JAWA BARAT                 3215
# ...
