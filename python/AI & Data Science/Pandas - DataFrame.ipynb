# %%
import pandas as pd

# %%
df = pd.DataFrame(data={"Nama": ["Efi", "Andi", "Ray"],
                       "umur" : [18, 21, 25],
                       "kelas" : [14, 10, 12]})

# %%
df
# Out:
#    Nama  umur  kelas
# 0   Efi    18     14
# 1  Andi    21     10
# 2   Ray    25     12

# %%
df.columns
# Out:
# Index(['Nama', 'umur', 'kelas'], dtype='object')

# %%
df.columns.values[2] = "Level"

# %%
df
# Out:
#    Nama  umur  Level
# 0   Efi    18     14
# 1  Andi    21     10
# 2   Ray    25     12

# %%
data = {
    "kalori": [420, 380, 390],
    "durasi": [50, 35, 40],
    "tekanan darah" : [120, 100, 110]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    kalori  durasi  tekanan darah
# 0     420      50            120
# 1     380      35            100
# 2     390      40            110

# %%
df.iloc[0:1, [0,2]]
# Out:
#    kalori  tekanan darah
# 0     420            120

# %%
df.iloc[: , 0:2]
# Out:
#    kalori  durasi
# 0     420      50
# 1     380      35
# 2     390      40

# %%
df.loc[0:2, :'kalori']
# Out:
#    kalori
# 0     420
# 1     380
# 2     390

# %%
df.loc[0:2, ['kalori', 'tekanan darah']]
# Out:
#    kalori  tekanan darah
# 0     420            120
# 1     380            100
# 2     390            110

# %%
type(df[['durasi']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['kalori'][1]
# Out:
# 380

# %%
df[['kalori']].loc[[1,2]]
# Out:
#    kalori
# 1     380
# 2     390

# %%
data = {
     "kalori": [420, 380, 390],
    "durasi": [50, 35, 40],
}

# %%
df = pd.DataFrame(data, index = ['data1', 'data2', 'data3'])

# %%
df
# Out:
#        kalori  durasi
# data1     420      50
# data2     380      35
# data3     390      40

# %%
df.iloc[0:2]
# Out:
#        kalori  durasi
# data1     420      50
# data2     380      35

# %%
df = pd.read_csv('./jumlah_usaha_pengaju..csv')

# %%
df
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    1             32    JAWA BARAT                 3201
# 1    2             32    JAWA BARAT                 3202
# 2    3             32    JAWA BARAT                 3203
# 3    4             32    JAWA BARAT                 3204
# 4    5             32    JAWA BARAT                 3205
# 5    6             32    JAWA BARAT                 3206
# 6    7             32    JAWA BARAT                 3207
# 7    8             32    JAWA BARAT                 3208
# 8    9             32    JAWA BARAT                 3209
# 9   10             32    JAWA BARAT                 3210
# 10  11             32    JAWA BARAT                 3211
# 11  12             32    JAWA BARAT                 3212
# 12  13             32    JAWA BARAT                 3213
# 13  14             32    JAWA BARAT                 3214
# 14  15             32    JAWA BARAT                 3215
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_usaha      satuan  tahun
# 0             6  UNIT USAHA   2021
# 1             0  UNIT USAHA   2021
# 2             0  UNIT USAHA   2021
# 3             3  UNIT USAHA   2021
# 4             0  UNIT USAHA   2021

# %%
df.tail()
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 22  23             32    JAWA BARAT                 3275         KOTA BEKASI
# 23  24             32    JAWA BARAT                 3276          KOTA DEPOK
# 24  25             32    JAWA BARAT                 3277         KOTA CIMAHI
# 25  26             32    JAWA BARAT                 3278    KOTA TASIKMALAYA
# 26  27             32    JAWA BARAT                 3279         KOTA BANJAR
#
#     jumlah_usaha      satuan  tahun
# 22             1  UNIT USAHA   2021
# 23             0  UNIT USAHA   2021
# 24             0  UNIT USAHA   2021
# 25             0  UNIT USAHA   2021
# 26             0  UNIT USAHA   2021

# %%
df.head(8)
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201
# 1   2             32    JAWA BARAT                 3202
# 2   3             32    JAWA BARAT                 3203
# 3   4             32    JAWA BARAT                 3204
# 4   5             32    JAWA BARAT                 3205
# 5   6             32    JAWA BARAT                 3206
# 6   7             32    JAWA BARAT                 3207
# 7   8             32    JAWA BARAT                 3208
#
#      nama_kabupaten_kota  jumlah_usaha      satuan  tahun
# 0        KABUPATEN BOGOR             6  UNIT USAHA   2021
# 1     KABUPATEN SUKABUMI             0  UNIT USAHA   2021
# 2      KABUPATEN CIANJUR             0  UNIT USAHA   2021
# 3      KABUPATEN BANDUNG             3  UNIT USAHA   2021
# 4        KABUPATEN GARUT             0  UNIT USAHA   2021
# 5  KABUPATEN TASIKMALAYA             0  UNIT USAHA   2021
# ...

# %%
df.tail(8)
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 19  20             32    JAWA BARAT                 3272       KOTA SUKABUMI
# 20  21             32    JAWA BARAT                 3273        KOTA BANDUNG
# 21  22             32    JAWA BARAT                 3274        KOTA CIREBON
# 22  23             32    JAWA BARAT                 3275         KOTA BEKASI
# 23  24             32    JAWA BARAT                 3276          KOTA DEPOK
# 24  25             32    JAWA BARAT                 3277         KOTA CIMAHI
# 25  26             32    JAWA BARAT                 3278    KOTA TASIKMALAYA
# 26  27             32    JAWA BARAT                 3279         KOTA BANJAR
#
#     jumlah_usaha      satuan  tahun
# 19             0  UNIT USAHA   2021
# 20             0  UNIT USAHA   2021
# 21             0  UNIT USAHA   2021
# 22             1  UNIT USAHA   2021
# 23             0  UNIT USAHA   2021
# 24             0  UNIT USAHA   2021
# ...

# %%
df.shape
# Out:
# (27, 8)

# %%
df.dtypes
# Out:
# id                      int64
# kode_provinsi           int64
# nama_provinsi          object
# kode_kabupaten_kota     int64
# nama_kabupaten_kota    object
# jumlah_usaha            int64
# satuan                 object
# tahun                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   27 non-null     int64
#  1   kode_provinsi        27 non-null     int64
#  2   nama_provinsi        27 non-null     object
#  3   kode_kabupaten_kota  27 non-null     int64
#  4   nama_kabupaten_kota  27 non-null     object
#  5   jumlah_usaha         27 non-null     int64
#  6   satuan               27 non-null     object
#  7   tahun                27 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 1.8+ KB

# %%
df.describe()
# Out:
#               id  kode_provinsi  kode_kabupaten_kota  jumlah_usaha   tahun
# count  27.000000           27.0            27.000000     27.000000    27.0
# mean   14.000000           32.0          3231.333333      0.444444  2021.0
# std     7.937254            0.0            31.796226      1.310705     0.0
# min     1.000000           32.0          3201.000000      0.000000  2021.0
# 25%     7.500000           32.0          3207.500000      0.000000  2021.0
# 50%    14.000000           32.0          3214.000000      0.000000  2021.0
# 75%    20.500000           32.0          3272.500000      0.000000  2021.0
# max    27.000000           32.0          3279.000000      6.000000  2021.0

# %%
df['jumlah_usaha'].mean()
# Out:
# 0.4444444444444444

# %%
df['jumlah_usaha'].mode()[0]
# Out:
# 0

# %%
df.corr()
# Out:
# /tmp/ipykernel_20054/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                            id  kode_provinsi  kode_kabupaten_kota  \
# id                   1.000000            NaN             0.891531
# kode_provinsi             NaN            NaN                  NaN
# kode_kabupaten_kota  0.891531            NaN             1.000000
# jumlah_usaha        -0.388187            NaN            -0.240872
# tahun                     NaN            NaN                  NaN
#
#                      jumlah_usaha  tahun
# id                      -0.388187    NaN
# kode_provinsi                 NaN    NaN
# kode_kabupaten_kota     -0.240872    NaN
# jumlah_usaha             1.000000    NaN
# tahun                         NaN    NaN
