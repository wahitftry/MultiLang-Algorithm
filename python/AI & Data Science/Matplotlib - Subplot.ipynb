# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoints = np.array([2,4,8,16])
ypoints = np.array([3,9,27,81])

plt.plot(xpoints, ypoints, 'o-')
plt.show()

# %%
xpoints = np.array([2,4,8,16])
ypoints = np.array([3,9,27,81])

plt.plot(xpoints, ypoints)
plt.show()

xpoints = np.array([4,32,16,90])
ypoints = np.array([5,25,25,75])

plt.plot(xpoints, ypoints)
plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(1,2,1)
plt.plot(x, y)

x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(1,2,2)
plt.plot(x, y)

plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(2,1,1)
plt.plot(x, y)

x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(2,1,2)
plt.plot(x, y)

plt.show()

# %%
#Plot 1
x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(2,3,1)
plt.plot(x, y)

# Plot 2
x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(2,3,2) 
plt.plot(x, y)

# Plot 3
x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(2,3,3) 
plt.plot(x, y)

# Plot 4
x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(2,3,4)
plt.plot(x, y)

# Plot 5
x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(2,3,5) 
plt.plot(x, y)

# Plot 6
x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(2,3,6)
plt.plot(x, y)

plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(1,2,1)
plt.plot(x, y)
plt.title('Sales')

x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(1,2,2)
plt.plot(x, y)
plt.title('Profit')

plt.show()

# %%
plt.figure(figsize=(15,5))

x = np.array([0,1,2,3])
y = np.array([30,80,50,75])

plt.subplot(1,2,1)
plt.plot(x, y)
plt.title('User')

x = np.array([0,1,2,3])
y = np.array([30,50,80,120])

plt.subplot(1,2,2)
plt.plot(x, y)
plt.title('Income')

plt.show()
